# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_csv('/content/IDEA.NS.csv')

data
# Out:
#            Date  Open  High   Low  Close  Adj Close     Volume
# 0    22-06-2022  8.40  8.70  8.20   8.55       8.55  135415425
# 1    23-06-2022  8.60  8.75  8.40   8.55       8.55   92828648
# 2    24-06-2022  8.65  8.80  8.55   8.75       8.75   77570510
# 3    27-06-2022  8.85  9.05  8.65   8.85       8.85   99812575
# 4    28-06-2022  8.85  9.00  8.75   8.85       8.85   73902850
# ..          ...   ...   ...   ...    ...        ...        ...
# 244  16-06-2023  7.85  8.00  7.75   7.80       7.80   70611505
# 245  19-06-2023  7.80  7.85  7.60   7.60       7.60   60944546
# 246  20-06-2023  7.60  7.65  7.35   7.40       7.40   76398916
# 247  21-06-2023  7.40  7.90  7.30   7.75       7.75  204458608
# 248  22-06-2023  7.70  7.85  7.40   7.45       7.45  178559291
#
# [249 rows x 7 columns]

# %%
x = data['Date']
y = data['Volume']

plt.xlabel("date")
plt.ylabel("volume")
plt.bar(x[-2:],y[-2:])
plt.show()
