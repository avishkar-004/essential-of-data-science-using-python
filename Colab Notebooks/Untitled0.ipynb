# %%
ename=[]
des=[]
sal=[]
dob=[]

f=open("EmpInfo.csv","r")
fc=f.read()
print("File content",fc)
lines=fc.split("\n")

for l in lines:
  words=l.split(",")
  ename.append(word[0])
  des.append(words[1])
  sal.append(words[2])
  dob.append(words[3])

print("\n\nName:",ename)
print("\n\nDesignation:",des)
print("\n\nSalary:",sal)
print("\n\nDOB:",dob)
print("Maximum salary:",max(sal))
print("Minimum salary:",min(sal))
print("Addition of salary:",sum(sal))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b08ce9f0880f> in <cell line: 6>()
#       4 dob=[]
#       5
# ----> 6 f=open("EmpInfo.csv","r")
#       7 fc=f.read()
#       8 print("File content",fc)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'EmpInfo.csv'

# %%
f=open("sampleFile.txt","x")
f.write("Please enter this line in my sample file")
f.close()

f=open("sampleFile.txt","r")
f.read()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-9-96ad9bf6fb9f> in <cell line: 1>()
# ----> 1 f=open("sampleFile.txt","x")
#       2 f.write("Please enter this line in my sample file")
#       3 f.close()
#       4
#       5 f=open("sampleFile.txt","r")
#
# FileExistsError: [Errno 17] File exists: 'sampleFile.txt'

# %%
f=open("/content/sampleFile.txt","a")
f.write("this line is to be appended in my file\n this is C3 batch \n  today attendence is too poor due to reexam")
f.close()

f.open("sampleFile.txt","r")
f.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-2c84f668c3bd> in <cell line: 5>()
#       3 f.close()
#       4
# ----> 5 f.open("sampleFile.txt","r")
#       6 f.read()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'open'

# %%
z=lambda a,b:a*b
print(z(5,4))
# Out:
# 20

# %%
a=20
def add (N)
  b=10
  print(a,b)
    def ad(25)
      c=30
      print(a,b,c)
  print(a,b,c)   
print(a,b,c)
# Out:
#   File "<ipython-input-19-c2bfabec9e1a>", line 2
#     def add (15)
#              ^
# SyntaxError: invalid syntax
