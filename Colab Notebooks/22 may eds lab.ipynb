# %%
Product_details=[]
Supplier_details=dict()
Customer_details=[]
gender={}


fp1=open("sales.csv","r")
data=fp1.readline()

while(True):

  data=fp1.readline()
  if not data:
    break;

  #print(data)
  #data=data.replace("\n","")
  temp=data.split(",")
  Product_details.append(temp[1])
  Customer_details.append(temp[3])
  Supplier_details.update({temp[0]:temp[2]})
  gender.update({temp[3]:temp[4]})  

fp1.close()

Customer_details=tuple(Customer_details)
print(type(Customer_details))
# Out:
# <class 'tuple'>

# %%
print("\nProduct detail\n",Product_details,end="")
print("\n\nCustomer detail\n",Customer_details,end="")
print("\n\nsupplier detail\n",Supplier_details,end="")
print("\n\nGender detail\n",gender,end="")
# Out:
# Product detail
#  ['Lenovo Laptop', 'Samsung M31', 'Realmi 10pro', 'Oppo F21', 'Lenovo Laptop', 'Samsung M31', '"LG TV 32"""', 'Oppo F21', 'Lenovo Laptop', 'Samsung M31', '"LG TV 32"""', 'Lenovo Laptop', 'Samsung M31', 'Realmi 10pro', 'Lenovo Laptop', 'Oppo F21', '"LG TV 32"""', 'Lenovo Laptop', 'Samsung M31', '"LG TV 32"""']
#
# Customer detail
#  ('Kaustubh Mahajan', 'Siddhi Kiwale', 'Sanket Kandalkar', 'Yash Mali', 'Yash Bagul', 'Siddhi Kiwale', 'Sanket Kandalkar', 'Kaustubh Mahajan', 'Yash Mali', 'Siddhi Kiwale', 'Sanket Kandalkar', 'Kaustubh Mahajan', 'Yash Mali', 'Siddhi Kiwale', 'Tanuja Mali', 'Kaustubh Mahajan', 'Sanket Kandalkar', 'Siddhi Kiwale', 'Kaustubh Mahajan', 'Yash Mali')
#
# supplier detail
# ...

# %%
frequency = {}#{lenovo Laptop : 3}
# interating over the list
for item in Product_details:
  #checking the elements in dictionary
  if item in frequency:
    #incrementing the counter
    frequency[item]+=1
    #initialising the counter
  else:
    frequency[item]=1
#priniting the frequency
print(frequency)
marklist = sorted(frequency.items(), key=lambda x:x[1],reverse=True)
sortdict = dict(marklist)
print(sortdict)
print("\n\nThe most populer product for sales ", list(sortdict.keys())[0],"sold",list(sortdict.values())[0],"times")
# Out:
# {'Lenovo Laptop': 6, 'Samsung M31': 5, 'Realmi 10pro': 2, 'Oppo F21': 3, '"LG TV 32"""': 4}
# {'Lenovo Laptop': 6, 'Samsung M31': 5, '"LG TV 32"""': 4, 'Oppo F21': 3, 'Realmi 10pro': 2}
#
#
# The most populer product for sales  Lenovo Laptop sold 6 times

# %%
frequency = {}
# interating over the list
for item in Supplier_details.values():
  #checking the elements in dictionary
  if item in frequency:
    #incrementing the counter
    frequency[item]+=1
    #initialising the counter
  else:
    frequency[item]=1
#priniting the frequency
print(frequency)
marklist = sorted(frequency.items(), key=lambda x:x[1],reverse=True)
sortdict = dict(marklist)
print(sortdict)
print("\n\nThe best Supplier for sales ", list(sortdict.keys())[0],"sold",list(sortdict.values())[0],"times")
# Out:
# {'Raka Ele.': 6, 'Vijay Sales': 3, 'Gada Ele.': 5, 'Surya Ele.': 4, 'Deshmukh sales': 2}
# {'Raka Ele.': 6, 'Gada Ele.': 5, 'Surya Ele.': 4, 'Vijay Sales': 3, 'Deshmukh sales': 2}
#
#
# The best Supplier for sales  Raka Ele. sold 6 times

# %%
frequency = {}
# interating over the list
for item in Customer_details:
  #checking the elements in dictionary
  if item in frequency:
    #incrementing the counter
    frequency[item]+=1
    #initialising the counter
  else:
    frequency[item]=1
#priniting the frequency
print(frequency)
marklist = sorted(frequency.items(), key=lambda x:x[1],reverse=True)
sortdict = dict(marklist)
print(sortdict)
print("\n\nMost time Customer", list(sortdict.keys())[0],"bought",list(sortdict.values())[0],"times")
# Out:
# {'Kaustubh Mahajan': 5, 'Siddhi Kiwale': 5, 'Sanket Kandalkar': 4, 'Yash Mali': 4, 'Yash Bagul': 1, 'Tanuja Mali': 1}
# {'Kaustubh Mahajan': 5, 'Siddhi Kiwale': 5, 'Sanket Kandalkar': 4, 'Yash Mali': 4, 'Yash Bagul': 1, 'Tanuja Mali': 1}
#
#
# Most time Customer Kaustubh Mahajan bought 5 times

# %%
frequency = {}
# interating over the list
for item in gender.values():
  #checking the elements in dictionary
  if item in frequency:
    #incrementing the counter
    frequency[item]+=1
    #initialising the counter
  else:
    frequency[item]=1
#priniting the frequency
print(frequency)
marklist = sorted(frequency.items(), key=lambda x:x[1],reverse=True)
sortdict = dict(marklist)
print(sortdict)
print("\n\nNo of",list(sortdict.keys())[1],"is",list(sortdict.values())[1])
# Out:
# {'Male\n': 4, 'Female\n': 2}
# {'Male\n': 4, 'Female\n': 2}
#
#
# No of Female
#  is 2

# %%
frequency = {}
# interating over the list
for item in gender.values():
  #checking the elements in dictionary
  if item in frequency:
    #incrementing the counter
    frequency[item]+=1
    #initialising the counter
  else:
    frequency[item]=1
#priniting the frequency
print(frequency)
marklist = sorted(frequency.items(), key=lambda x:x[1],reverse=True)
sortdict = dict(marklist)
print(sortdict)
print("\nNo of female is",sortdict["Female\n"])
# Out:
# {'Male\n': 4, 'Female\n': 2}
# {'Male\n': 4, 'Female\n': 2}
#
# No of female is 2

# %%
from collections import Counter
counter = dict(Counter(gender))
names = list(counter.keys())
print(names)
male=0
female=0

for name in names:
  if gender[name]=="Male\n":
    male=male+1
  if gender[name]=="Female\n":
    female=female+1

print("Total no of Males :",male)
print("Total no of Females :",female)
# Out:
# ['Kaustubh Mahajan', 'Siddhi Kiwale', 'Sanket Kandalkar', 'Yash Mali', 'Yash Bagul', 'Tanuja Mali']
# Total no of Males : 4
# Total no of Females : 2
