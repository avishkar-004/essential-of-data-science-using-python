# %%
a=int(input())
if(a%2==0):
 print("yes")
else:
 print("no")

# %%
a=int(input())
if(a%5==0):
 print("yes")
else:
 print("no")

# %%
a=int(input())
if(a>=0):
 print("yes")
else:
 print("no")

# %%
# if else conditions
a=int(input())
if(a%5==0):
    print("divisible by 5")
elif(a%3==0):
    print("divisible by 3")
elif(a%2==0):
    print("divisible by 3")
else:
    print("none")

# %%
# square of no. in loops
i=0
while(i<15):
 print(i,"=",i*i)
 i+=1
else:
 print("End")

# %%
#print square by For loop
n=int(input())
i=0
for i in range (1,n+1,1):
 print(i,"=",i*i)
 i+=1

# %%
#cube of odd no from 10 to 20
i=0
for i in range (10,20,1):
 if(i%2==1):
  print(i,"=",i*i*i)
 i+=1
