# %%
import csv
from datetime import date 
from datetime import datetime 

def calculateAge(birthDate):
    today = date.today()
    age = (today.year - birthDate.year) - ((today.month, today.day) < (birthDate.month, birthDate.day))
    return age



f1 = open("/content/DATA.csv","r")

data = list(csv.reader(f1))
bdate = []
age = []
dollars = []

for i in range(len(data)):  
    print(data[i][1])
    bdate.append(datetime.strptime(data[i][1],'%d/%m/%Y').date())
    
print(bdate)    
for i in range(len(data)):
    age.append(calculateAge(bdate[i]))
    dollars.append(float(data[i][2])/82)
print((dollars))
print("Age",age)

f1.close()
# Out:
# 17/02/2004
# 12/4/2004
# 23/08/2003
# 16/10/2004
# 17/01/2003
# [datetime.date(2004, 2, 17), datetime.date(2004, 4, 12), datetime.date(2003, 8, 23), datetime.date(2004, 10, 16), datetime.date(2003, 1, 17)]
# [1463.4146341463415, 6896.048780487805, 9556.987804878048, 1749.4634146341464, 1681.5975609756097]
# Age [19, 19, 19, 18, 20]

# %%
import csv
import datetime
from datetime import date
from datetime import datetime

def calculate_age():
  today = date.today()
  age = today.year - today.month 
  return age

f = open("/content/DATA.csv","r")
contents=f.read()
lines=contents.split("\n")
print(lines)

nm = [] ; age = []; sal = []

for i in range(len(lines)):
  print(lines[i][1])
  b_date.append(datetime.strptime(data[i][1],"%d%m%%y").date())

for l in lines :
  words = l.split(",")
  print(words)
# Out:
# ['A,17/02/2004,120000', 'B,12/4/2004,565476', 'C,23/08/2003,783673', 'D,16/10/2004,143456', 'E,17/01/2003,137891', '']
# ,
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-3186948fb763> in <cell line: 18>()
#      18 for i in range(len(lines)):
#      19   print(lines[i][1])
# ---> 20   b_date.append(datetime.strptime(data[i][1],"%d%m%%y").date())
#      21
#      22 for l in lines :
#
# IndexError: list index out of range

# %%
# Create a dictionary with a list of two-item tuples
L = [('name', 'bob'),
     ('age',25),
     ('job', 'dev')]

D = dict(L)
print(D)
# Out:
# {'name': 'bob', 'age': 25, 'job': 'dev'}
