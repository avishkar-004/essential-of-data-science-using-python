# %%
list1=[13,84,478,476,92,46]
print(sort(list1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-35f24303b1ab> in <cell line: 2>()
#       1 list1=[13,84,478,476,92,46]
# ----> 2 print(sort(list1))
#
# NameError: name 'sort' is not defined
