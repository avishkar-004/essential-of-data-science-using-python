# %%
roll=list()
eds=list()


f=open("testmarks1.csv","r")
data=f.readline()
while(True):

  data=f.readline()
  if not data:
    break;
  print(data)
  temp=data.split(",")
  roll.append(int(temp[0]))
  eds.append(float(temp[1]))
# Out:
# 801,43.05
#
# 802,43.47
#
# 803,42.24
#
# 804,39.24
#
# 805,40.9
#
# 806,39.47
#
# 807,41.68
#
# 808,42.19
#
# 809,44.75
#
# 810,46.95

# %%
import numpy as np

# %%
a = np.array(roll)
print (a)
# Out:
# [801 802 803 804 805 806 807 808 809 810]
